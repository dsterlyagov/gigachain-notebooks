# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                              chunk_overlap=100)

# %%
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import CharacterTextSplitter
import nltk

# Удаление и переустановка данных
#nltk.data.path.append('/root/nltk_data')
nltk.download('punkt', force=True)
# Out:
# pytesseract is not installed. Cannot use the ocr_only partitioning strategy. Falling back to partitioning with another strategy.
# Falling back to partitioning with hi_res.
# Failed to get OCRAgent instance: No module named 'unstructured_pytesseract'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\utils\ocr_models\ocr_interface.py:47, in OCRAgent.get_instance(ocr_agent_module, language)
#      46 try:
# ---> 47     module = importlib.import_module(module_name)
#      48     loaded_class = getattr(module, class_name)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\utils\ocr_models\tesseract_ocr.py:9
#       8 import pandas as pd
# ----> 9 import unstructured_pytesseract
#      10 from PIL import Image as PILImage
#
# ModuleNotFoundError: No module named 'unstructured_pytesseract'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 9
#       7 # Загрузка и разделение текста
#       8 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
# ----> 9 splitted_data = loader.load_and_split(text_splitter)
#      11 # Вывод результата
#      12 print(splitted_data)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\langchain_core\document_loaders\base.py:64, in BaseLoader.load_and_split(self, text_splitter)
#      62 else:
#      63     _text_splitter = text_splitter
# ---> 64 docs = self.load()
#      65 return _text_splitter.split_documents(docs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\langchain_core\document_loaders\base.py:30, in BaseLoader.load(self)
#      28 def load(self) -> List[Document]:
#      29     """Load data into Document objects."""
# ---> 30     return list(self.lazy_load())
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\langchain_community\document_loaders\pdf.py:74, in UnstructuredPDFLoader._get_elements(self)
#      71 def _get_elements(self) -> List:
#      72     from unstructured.partition.pdf import partition_pdf
# ---> 74     return partition_pdf(filename=self.file_path, **self.unstructured_kwargs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\documents\elements.py:605, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     603 @functools.wraps(func)
#     604 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 605     elements = func(*args, **kwargs)
#     606     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     608     regex_metadata: dict["str", "str"] = call_args.get("regex_metadata", {})
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\file_utils\filetype.py:731, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     729 @functools.wraps(func)
#     730 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 731     elements = func(*args, **kwargs)
#     732     params = get_call_args_applying_defaults(func, *args, **kwargs)
#     733     include_metadata = params.get("include_metadata", True)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\file_utils\filetype.py:687, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     685 @functools.wraps(func)
#     686 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 687     elements = func(*args, **kwargs)
#     688     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     689     include_metadata = call_args.get("include_metadata", True)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf.py:210, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     206 exactly_one(filename=filename, file=file)
#     208 languages = check_language_args(languages or [], ocr_languages)
# --> 210 return partition_pdf_or_image(
#     211     filename=filename,
#     212     file=file,
#     213     include_page_breaks=include_page_breaks,
#     214     strategy=strategy,
#     215     infer_table_structure=infer_table_structure,
#     216     languages=languages,
#     217     metadata_last_modified=metadata_last_modified,
#     218     hi_res_model_name=hi_res_model_name,
#     219     extract_images_in_pdf=extract_images_in_pdf,
#     220     extract_image_block_types=extract_image_block_types,
#     221     extract_image_block_output_dir=extract_image_block_output_dir,
#     222     extract_image_block_to_payload=extract_image_block_to_payload,
#     223     date_from_file_object=date_from_file_object,
#     224     starting_page_number=starting_page_number,
#     225     extract_forms=extract_forms,
#     226     form_extraction_skip_tables=form_extraction_skip_tables,
#     227     **kwargs,
#     228 )
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf.py:312, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, languages, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     310     with warnings.catch_warnings():
#     311         warnings.simplefilter("ignore")
# --> 312         elements = _partition_pdf_or_image_local(
#     313             filename=filename,
#     314             file=spooled_to_bytes_io_if_needed(file),
#     315             is_image=is_image,
#     316             infer_table_structure=infer_table_structure,
#     317             include_page_breaks=include_page_breaks,
#     318             languages=languages,
#     319             ocr_languages=ocr_languages,
#     320             metadata_last_modified=metadata_last_modified or last_modification_date,
#     321             hi_res_model_name=hi_res_model_name,
#     322             pdf_text_extractable=pdf_text_extractable,
#     323             extract_images_in_pdf=extract_images_in_pdf,
#     324             extract_image_block_types=extract_image_block_types,
#     325             extract_image_block_output_dir=extract_image_block_output_dir,
#     326             extract_image_block_to_payload=extract_image_block_to_payload,
#     327             starting_page_number=starting_page_number,
#     328             extract_forms=extract_forms,
#     329             form_extraction_skip_tables=form_extraction_skip_tables,
#     330             **kwargs,
#     331         )
#     332         out_elements = _process_uncategorized_text_elements(elements)
#     334 elif strategy == PartitionStrategy.FAST:
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\utils.py:217, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     214 @wraps(func)
#     215 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     216     run_check()
# --> 217     return func(*args, **kwargs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf.py:647, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_languages, ocr_mode, model_name, hi_res_model_name, pdf_image_dpi, metadata_last_modified, pdf_text_extractable, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, analysis, analyzed_image_output_dir_path, starting_page_number, extract_forms, form_extraction_skip_tables, pdf_hi_res_max_pages, **kwargs)
#     640         # NOTE(christine): merged_document_layout = extracted_layout + inferred_layout
#     641         merged_document_layout = merge_inferred_with_extracted_layout(
#     642             inferred_document_layout=inferred_document_layout,
#     643             extracted_layout=extracted_layout,
#     644             hi_res_model_name=hi_res_model_name,
#     645         )
# --> 647         final_document_layout = process_file_with_ocr(
#     648             filename,
#     649             merged_document_layout,
#     650             extracted_layout=extracted_layout,
#     651             is_image=is_image,
#     652             infer_table_structure=infer_table_structure,
#     653             ocr_languages=ocr_languages,
#     654             ocr_mode=ocr_mode,
#     655             pdf_image_dpi=pdf_image_dpi,
#     656             ocr_drawer=ocr_drawer,
#     657         )
#     658 else:
#     659     inferred_document_layout = process_data_with_model(
#     660         file,
#     661         is_image=is_image,
#     662         model_name=hi_res_model_name,
#     663         pdf_image_dpi=pdf_image_dpi,
#     664     )
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\utils.py:217, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     214 @wraps(func)
#     215 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     216     run_check()
# --> 217     return func(*args, **kwargs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf_image\ocr.py:176, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_languages, ocr_mode, pdf_image_dpi, ocr_drawer)
#     174 except Exception as e:
#     175     if os.path.isdir(filename) or os.path.isfile(filename):
# --> 176         raise e
#     177     else:
#     178         raise FileNotFoundError(f'File "{filename}" not found!') from e
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf_image\ocr.py:163, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_languages, ocr_mode, pdf_image_dpi, ocr_drawer)
#     161     extracted_regions = extracted_layout[i] if i < len(extracted_layout) else None
#     162     with PILImage.open(image_path) as image:
# --> 163         merged_page_layout = supplement_page_layout_with_ocr(
#     164             page_layout=out_layout.pages[i],
#     165             image=image,
#     166             infer_table_structure=infer_table_structure,
#     167             ocr_languages=ocr_languages,
#     168             ocr_mode=ocr_mode,
#     169             extracted_regions=extracted_regions,
#     170             ocr_drawer=ocr_drawer,
#     171         )
#     172         merged_page_layouts.append(merged_page_layout)
#     173 return DocumentLayout.from_pages(merged_page_layouts)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\utils.py:217, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     214 @wraps(func)
#     215 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     216     run_check()
# --> 217     return func(*args, **kwargs)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\pdf_image\ocr.py:199, in supplement_page_layout_with_ocr(page_layout, image, infer_table_structure, ocr_languages, ocr_mode, extracted_regions, ocr_drawer)
#     181 @requires_dependencies("unstructured_inference")
#     182 def supplement_page_layout_with_ocr(
#     183     page_layout: "PageLayout",
#    (...)
#     189     ocr_drawer: Optional[OCRLayoutDrawer] = None,
#     190 ) -> "PageLayout":
#     191     """
#     192     Supplement an PageLayout with OCR results depending on OCR mode.
#     193     If mode is "entire_page", we get the OCR layout for the entire image and
#    (...)
#     196     with no text and add text from OCR to each element.
#     197     """
# --> 199     ocr_agent = OCRAgent.get_agent(language=ocr_languages)
#     200     if ocr_mode == OCRMode.FULL_PAGE.value:
#     201         ocr_layout = ocr_agent.get_layout_from_image(image)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\utils\ocr_models\ocr_interface.py:34, in OCRAgent.get_agent(cls, language)
#      29 """Get the configured OCRAgent instance.
#      30
#      31 The OCR package used by the agent is determined by the `OCR_AGENT` environment variable.
#      32 """
#      33 ocr_agent_cls_qname = cls._get_ocr_agent_cls_qname()
# ---> 34 return cls.get_instance(ocr_agent_cls_qname, language)
#
# File c:\users\professional\pycharmprojects\gigachain\venv\lib\site-packages\unstructured\partition\utils\ocr_models\ocr_interface.py:52, in OCRAgent.get_instance(ocr_agent_module, language)
#      50 except (ImportError, AttributeError) as e:
#      51     logger.error(f"Failed to get OCRAgent instance: {e}")
# ---> 52     raise RuntimeError(
#      53         "Could not get the OCRAgent instance. Please check the OCR package and the "
#      54         "OCR_AGENT environment variable."
#      55     )
#
# RuntimeError: Could not get the OCRAgent instance. Please check the OCR package and the OCR_AGENT environment variable.

# %%
import pytesseract

try:
    text = pytesseract.image_to_string('path_to_your_image.png')
    print(text)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
pdf_file = 'claster.pdf'
loader = UnstructuredPDFLoader(pdf_file)

# %%
splitted_data = loader.load_and_split(text_splitter)
